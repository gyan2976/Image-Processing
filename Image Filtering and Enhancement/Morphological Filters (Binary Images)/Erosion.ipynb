# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Libraries**

# %%
import numpy as nup
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import cv2
from PIL import Image, ImageDraw, ImageFilter
import glob 
# %matplotlib inline

# %% [markdown]
# **Original Image**

# %%
kid = Image.open('/content/drive/MyDrive/Computer Vision/Image Processing/Data/kid.jpg')
plt.imshow(kid)
plt.show()

# %%
shraddha = Image.open('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg')
plt.imshow(shraddha)
plt.show()

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/drive/MyDrive/Computer Vision/Image Processing/Data/kid.jpg")

# Creating kernel
kernel = np.ones((3, 3), np.uint8)
# Using cv2.erode() method 
image_erode = cv2.erode(image, kernel)

filename = 'image_erode1.jpg'
# Using cv2.imwrite() method
# Saving the image
#cv2.imwrite(filename, image_erode)

cv2_imshow(image_erode)
# Out:
# <PIL.Image.Image image mode=RGB size=720x479 at 0x7FBEA2016CD0>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/drive/MyDrive/Computer Vision/Image Processing/Data/kid.jpg")

# Creating kernel
kernel = np.ones((5, 5), np.uint8)
# Using cv2.erode() method 
image_erode = cv2.erode(image, kernel)

filename = 'image_erode1.jpg'
# Using cv2.imwrite() method
# Saving the image
#cv2.imwrite(filename, image_erode)

cv2_imshow(image_erode)
# Out:
# <PIL.Image.Image image mode=RGB size=720x479 at 0x7FBEA14E5190>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg")

# Creating kernel
kernel = np.ones((3, 3), np.uint8)
# Using cv2.erode() method 
image_erode = cv2.erode(image, kernel)

filename = 'image_erode1.jpg'
# Using cv2.imwrite() method
# Saving the image
#cv2.imwrite(filename, image_erode)

cv2_imshow(image_erode)
# Out:
# <PIL.Image.Image image mode=RGB size=585x966 at 0x7FBEA1533F50>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg")

# Creating kernel
kernel = np.ones((5, 5), np.uint8)
# Using cv2.erode() method 
image_erode = cv2.erode(image, kernel)

filename = 'image_erode1.jpg'
# Using cv2.imwrite() method
# Saving the image
#cv2.imwrite(filename, image_erode)

cv2_imshow(image_erode)
# Out:
# <PIL.Image.Image image mode=RGB size=585x966 at 0x7FBEA1501E90>
