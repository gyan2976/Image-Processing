# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import os 
import glob 
# %matplotlib inline

# %% [markdown]
# #**Open a particular image from a path: (Read 1 image)**

# %% [markdown]
# **Using OpenCV**

# %%
#Read the image in original format

img = cv2.imread('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.grid(False)
plt.imshow(img)
plt.show()

# %%
#Read image in gray scale format

#img = cv2.imread('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg', 0) 
#plt.imshow(img, cmap='gray')

#im = cv2.imread('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg', cv2.IMREAD_GRAYSCALE)
#plt.imshow(im)

im = cv2.imread('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg')
plt.imshow(im)

# %% [markdown]
# **Using PIL**

# %%
image = Image.open("/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg")
image.show()  #Read but no output

# %%
im = Image.open('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg')
plt.imshow(im)
plt.show()

# %% [markdown]
# **Using Matplotlib**

# %%
import matplotlib.pyplot as plt

image = plt.imread('/content/drive/MyDrive/Computer Vision/Image Processing/Data/fort.jpg')
plt.imshow(image)

# %% [markdown]
# **Using try and except**

# %%
try:
 img = Image.open('/content/drive/MyDrive/Computer Vision/Image Processing/Data/fort.jpg')
except IOError:
 pass

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x408 at 0x7F153A5E3C50>

# %% [markdown]
# #**Read multiple image from a folder**

# %% [markdown]
# **Using Glob**

# %%
import cv2
import numpy
import glob

folders = glob.glob('/content/drive/MyDrive/Computer Vision/Image Processing/Data')
imagenames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.jpg'):
        imagenames_list.append(f)

read_images = []        
for image in imagenames_list:
    read_images.append(cv2.imread(image, cv2.IMREAD_GRAYSCALE))

# %%
imagenames_list
# Out:
# ['/content/drive/MyDrive/Computer Vision/Image Processing/Data/fort.jpg',
#  '/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg']

# %%
read_images
# Out:
# [array([[137, 137, 137, ..., 197, 197, 198],
#         [137, 137, 137, ..., 197, 198, 198],
#         [138, 138, 138, ..., 198, 198, 199],
#         ...,
#         [ 56,  50,  77, ...,  91,  73,  71],
#         [ 46,  64,  82, ..., 111,  93,  73],
#         [ 41,  77,  54, ..., 101,  99,  76]], dtype=uint8),
#  array([[204, 203, 203, ..., 174, 175, 174],
#         [204, 204, 204, ..., 175, 175, 175],
#         [204, 204, 204, ..., 175, 176, 176],
#         ...,
#         [217, 216, 216, ..., 195, 194, 195],
#         [217, 216, 216, ..., 194, 193, 194],
#         [215, 215, 214, ..., 192, 191, 189]], dtype=uint8)]

# %%
plt.imshow(read_images[0])

# %%
plt.imshow(read_images[1])

# %%
#Set the path where images are stored 

img_dir = "/content/drive/MyDrive/Computer Vision/Image Processing/Data" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*jpg') 
files = glob.glob(data_path) 
data = [] 
for f1 in files: 
    img1 = cv2.imread(f1) 
    data.append(img1) 
    plt.figure() 
    plt.imshow(img1)
