# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import os 
import glob 
# %matplotlib inline

# %% [markdown]
# **Path**

# %%
#path = '/content/drive/MyDrive/Computer Vision/Image Processing/Data/'

# %% [markdown]
# #**Using PIL**

# %%
#Original image
im1 = Image.open('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg')
plt.imshow(im1)
plt.show()

# %%
#Cropped image
#crop(left, upper left, right, bottom right)
im = Image.open('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg').convert('L')
im = im.crop((100,200,300,400))
plt.imshow(im)
plt.show()

# %%
#Cropped image
#crop(left, upper, right, lower)
im = Image.open('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg').convert('L')
im = im.crop((100, 100, 200, 200))
plt.imshow(im)
plt.show()

# %% [markdown]
# #**Using Cv2**

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


#crop_img = img[y:y+h, x:x+w]
crop_img = img[0:280, 150:330]

#cv2.imshow("cropped", crop_img)
cv2_imshow(crop_img)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=180x280 at 0x7F1FE0A4E590>
# -1
